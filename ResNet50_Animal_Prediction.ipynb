# %%
#Importing pre trained deep-learning framework , restNet 50 pretrained on image-net data
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np
from skimage.io import imread
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
model = ResNet50(weights='imagenet') #import pre-trained model , download
img_path = 'img.jpg' #set path to image for analysis

# %%
img=imread(img_path)

# %%
plt.imshow(img)

# %%
#loading the image
img = image.load_img(img_path, target_size=(224,224)) 
#convert image to array , 2D
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
#preprocess data and get ready for prediction
x = preprocess_input(x)

# %%
#predicting the values
preds=model.predict(x)

# %%
#predicting the animal
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/imagenet_class_index.json
# 40960/35363 [==================================] - 0s 3us/step
# Predicted: [('n02106662', 'German_shepherd', 0.99764234), ('n02105162', 'malinois', 0.0005446877), ('n02105056', 'groenendael', 0.00043399914)]
